# %%
data = [(1, ([31, 12, 82, 42, 58], 1.0)),
 (2, ([18, 94, 15, 51, 68], 1.0)),
 (3, ([41, 17, 82, 87, 52], 1.0)),
 (4, ([72, 82, 71, 84, 3, 7, 46], 1.0)),
 (5, ([65, 47, 22, 59, 53, 90], 1.0)),
 (6, ([61, 24], 1.0)),
 (7, ([31, 70, 11, 48, 9, 56], 1.0)),
 (8, ([52, 62, 30, 10], 1.0)),
 (9, ([74, 59, 72, 35, 91, 71], 1.0)),
 (10, ([75, 68, 81, 93, 8, 94, 34], 1.0)),
 (11, ([92, 41, 84, 2, 77, 70, 54], 1.0)),
 (12, ([14, 31, 8, 85, 54], 1.0)),
 (13, ([31, 43, 100, 89, 40, 35, 84], 1.0)),
 (14, ([68], 1.0)),
 (15, ([1, 38], 1.0)),
 (16, ([17, 71, 92, 63, 79], 1.0)),
 (17, ([99], 1.0)),
 (18, ([21], 1.0)),
 (19, ([89, 95, 20, 49], 1.0)),
 (20, ([84, 98, 9, 72, 32], 1.0)),
 (21, ([29, 7], 1.0)),
 (22, ([64, 94, 49, 46, 48, 100], 1.0)),
 (23, ([99, 76, 84, 30], 1.0)),
 (24, ([10, 8, 73, 49], 1.0)),
 (25, ([], 1.0)),
 (26, ([], 1.0)),
 (27, ([32], 1.0)),
 (28, ([], 1.0)),
 (29, ([68, 41, 25, 14, 84, 38], 1.0)),
 (30, ([83, 65, 8, 72, 73], 1.0)),
 (31, ([37, 8, 21, 24], 1.0)),
 (32, ([100, 34], 1.0)),
 (33, ([97, 2, 75, 99, 78, 96, 67], 1.0)),
 (34, ([], 1.0)),
 (35, ([18, 26], 1.0)),
 (36, ([24], 1.0)),
 (37, ([39, 22], 1.0)),
 (38, ([86, 97], 1.0)),
 (39, ([68, 78, 81, 99, 29, 80], 1.0)),
 (40, ([21], 1.0)),
 (41, ([], 1.0)),
 (42, ([96], 1.0)),
 (43, ([56, 93, 7, 33, 59], 1.0)),
 (44, ([66, 47], 1.0)),
 (45, ([], 1.0)),
 (46, ([85, 5, 29], 1.0)),
 (47, ([32, 61, 49, 97], 1.0)),
 (48, ([84], 1.0)),
 (49, ([], 1.0)),
 (50, ([42, 90, 34], 1.0)),
 (51, ([23, 3, 92], 1.0)),
 (52, ([11, 9, 85], 1.0)),
 (53, ([83, 88, 27, 40, 32, 76], 1.0)),
 (54, ([51, 30, 18, 85, 83, 25, 47], 1.0)),
 (55, ([40, 82, 63, 5, 58], 1.0)),
 (56, ([90, 71, 93, 59, 68, 89], 1.0)),
 (57, ([87, 53, 52, 31, 2, 92], 1.0)),
 (58, ([56, 35, 81], 1.0)),
 (59, ([84, 98], 1.0)),
 (60, ([81, 63, 76, 87, 100], 1.0)),
 (61, ([35, 82, 5, 41], 1.0)),
 (62, ([21, 36], 1.0)),
 (63, ([59, 14], 1.0)),
 (64, ([55, 66, 73, 10], 1.0)),
 (65, ([21, 61, 33, 9, 37], 1.0)),
 (66, ([88, 98, 61, 71, 68, 38], 1.0)),
 (67, ([93, 29, 97, 60, 44], 1.0)),
 (68, ([49, 94, 75, 45], 1.0)),
 (69, ([42], 1.0)),
 (70, ([48, 26, 25, 3, 53, 81, 65], 1.0)),
 (71, ([34, 69, 8], 1.0)),
 (72, ([71, 75, 44, 54], 1.0)),
 (73, ([86, 23, 70, 83, 84, 2, 53], 1.0)),
 (74, ([], 1.0)),
 (75, ([50, 28, 85, 72], 1.0)),
 (76, ([], 1.0)),
 (77, ([55, 85, 61, 99, 75, 33, 73], 1.0)),
 (78, ([28], 1.0)),
 (79, ([40, 95, 75, 65], 1.0)),
 (80, ([10], 1.0)),
 (81, ([15, 92], 1.0)),
 (82, ([14, 87, 89, 9, 67], 1.0)),
 (83, ([33, 31, 15, 32, 52], 1.0)),
 (84, ([67, 94, 91, 78, 73, 45, 89], 1.0)),
 (85, ([], 1.0)),
 (86, ([18, 56], 1.0)),
 (87, ([70, 11, 13, 16, 14, 73], 1.0)),
 (88, ([68, 24, 67, 17, 91], 1.0)),
 (89, ([52, 29, 31, 54, 28, 90, 56], 1.0)),
 (90, ([96, 94], 1.0)),
 (91, ([21, 54], 1.0)),
 (92, ([56, 66, 68, 69, 31], 1.0)),
 (93, ([49, 94, 73, 38, 74, 44, 37], 1.0)),
 (94, ([75, 76, 83, 85], 1.0)),
 (95, ([87, 53], 1.0)),
 (96, ([60, 26, 61, 80, 78], 1.0)),
 (97, ([86, 81, 98, 91, 56, 18], 1.0)),
 (98, ([74, 46], 1.0)),
 (99, ([12, 31, 36, 28, 10, 5, 88], 1.0)),
 (100, ([56, 62], 1.0))]

# %%
# Convert the data into the desired format
space_seperated_data = {}
for node, (neighbors, _) in data:
    if neighbors:
        space_seperated_data[node] = {str(neighbor): 1 for neighbor in neighbors}
    else:
        space_seperated_data[node] = {}

# Write the data to a file
with open("space_seperated_data.txt", "w") as f:
    for node, neighbors in space_seperated_data.items():
        f.write(f"{node} {neighbors}\n")

## space_seperated_data.txt
# 1 {'31': 1, '12': 1, '82': 1, '42': 1, '58': 1}
# 2 {'18': 1, '94': 1, '15': 1, '51': 1, '68': 1}
# 3 {'41': 1, '17': 1, '82': 1, '87': 1, '52': 1}

# %%
adjacency_list = {}
for node, (neighbors, _) in data:
    adjacency_list[node] = neighbors

# Write the data to a file
with open("adjacency_list.txt", "w") as f:
    for node, neighbors in adjacency_list.items():
        f.write(f"{node} {' '.join(map(str, neighbors))}\n")

# 1 31 12 82 42 58
# 2 18 94 15 51 68
# 3 41 17 82 87 52

# %%
# link_data = {}

# for node,(neighbors,_) in data:
#   link_data[node] = neighbors


# with open("adjacency_list.txt", "r") as f:
#   for node, neighbors in link_data.strip().split('\n'):
#     values = list(map(int, line.split()))
#     link_data[values[0]] = values[1:]

# print(link_data)

# %%
link_data = {
    1: [31, 12, 82, 42, 58],
    2: [18, 94, 15, 51, 68],
    3: [41, 17, 82, 87, 52],
    4: [72, 82, 71, 84, 3, 7, 46],
    5: [65, 47, 22, 59, 53, 90],
    6: [61, 24],
    7: [31, 70, 11, 48, 9, 56],
    8: [52, 62, 30, 10],
    9: [74, 59, 72, 35, 91, 71],
    10: [75, 68, 81, 93, 8, 94, 34],
    11: [92, 41, 84, 2, 77, 70, 54],
    12: [14, 31, 8, 85, 54],
    13: [31, 43, 100, 89, 40, 35, 84],
    14: [68],
    15: [1, 38],
    16: [17, 71, 92, 63, 79],
    17: [99],
    18: [21],
    19: [89, 95, 20, 49],
    20: [84, 98, 9, 72, 32],
    21: [29, 7],
    22: [64, 94, 49, 46, 48, 100],
    23: [99, 76, 84, 30],
    24: [10, 8, 73, 49],
    25: [],
    26: [],
    27: [32],
    28: [],
    29: [68, 41, 25, 14, 84, 38],
    30: [83, 65, 8, 72, 73],
    31: [37, 8, 21, 24],
    32: [100, 34],
    33: [97, 2, 75, 99, 78, 96, 67],
    34: [],
    35: [18, 26],
    36: [24],
    37: [39, 22],
    38: [86, 97],
    39: [68, 78, 81, 99, 29, 80],
    40: [21],
    41: [],
    42: [96],
    43: [56, 93, 7, 33, 59],
    44: [66, 47],
    45: [],
    46: [85, 5, 29],
    47: [32, 61, 49, 97],
    48: [84],
    49: [],
    50: [42, 90, 34],
    51: [23, 3, 92],
    52: [11, 9, 85],
    53: [83, 88, 27, 40, 32, 76],
    54: [51, 30, 18, 85, 83, 25, 47],
    55: [40, 82, 63, 5, 58],
    56: [90, 71, 93, 59, 68, 89],
    57: [87, 53, 52, 31, 2, 92],
    58: [56, 35, 81],
    59: [84, 98],
    60: [81, 63, 76, 87, 100],
    61: [35, 82, 5, 41],
    62: [21, 36],
    63: [59, 14],
    64: [55, 66, 73, 10],
    65: [21, 61, 33, 9, 37],
    66: [88, 98, 61, 71, 68, 38],
    67: [93, 29, 97, 60, 44],
    68: [49, 94, 75, 45],
    69: [42],
    70: [48, 26, 25, 3, 53, 81, 65],
    71: [34, 69, 8],
    72: [71, 75, 44, 54],
    73: [86, 23, 70, 83, 84, 2, 53],
    74: [],
    75: [50, 28, 85, 72],
    76: [],
    77: [55, 85, 61, 99, 75, 33, 73],
    78: [28],
    79: [40, 95, 75, 65],
    80: [10],
    81: [15, 92],
    82: [14, 87, 89, 9, 67],
    83: [33, 31, 15, 32, 52],
    84: [67, 94, 91, 78, 73, 45, 89],
    85: [],
    86: [18, 56],
    87: [70, 11, 13, 16, 14, 73],
    88: [68, 24, 67, 17, 91],
    89: [52, 29, 31, 54, 28, 90, 56],
    90: [96, 94],
    91: [21, 54],
    92: [56, 66, 68, 69, 31],
    93: [49, 94, 73, 38, 74, 44, 37],
    94: [75, 76, 83, 85],
    95: [87, 53],
    96: [60, 26, 61, 80, 78],
    97: [86, 81, 98, 91, 56, 18],
    98: [74, 46],
    99: [12, 31, 36, 28, 10, 5, 88],
    100: [56, 62]
}

# %% [markdown]
# # For Spark Input

# %%
spark_input_file = "spark_input.txt"

# Open the file in write mode
with open(spark_input_file, "w") as file:
    # Write the key-value pairs to the file in the desired format
    for key, values in link_data.items():
        for value in values:
            file.write(f"{key} {value}\n")

print(f"Data has been saved to {spark_input_file}")

# 1 31
# 1 12
# 1 82
# 1 42
# 1 58
# 2 18
# 2 94
# 2 15
# Out:
# Data has been saved to spark_input.txt

# %%
# make all node indices to 0 indexed
link_data_0_indexed = {key: [value - 1 for value in values] for key, values in link_data.items()}

link_data_0_indexed = {key - 1: [value - 1 for value in values] for key, values in link_data_0_indexed.items()}

print(link_data_0_indexed)
# Out:
# {0: [29, 10, 80, 40, 56], 1: [16, 92, 13, 49, 66], 2: [39, 15, 80, 85, 50], 3: [70, 80, 69, 82, 1, 5, 44], 4: [63, 45, 20, 57, 51, 88], 5: [59, 22], 6: [29, 68, 9, 46, 7, 54], 7: [50, 60, 28, 8], 8: [72, 57, 70, 33, 89, 69], 9: [73, 66, 79, 91, 6, 92, 32], 10: [90, 39, 82, 0, 75, 68, 52], 11: [12, 29, 6, 83, 52], 12: [29, 41, 98, 87, 38, 33, 82], 13: [66], 14: [-1, 36], 15: [15, 69, 90, 61, 77], 16: [97], 17: [19], 18: [87, 93, 18, 47], 19: [82, 96, 7, 70, 30], 20: [27, 5], 21: [62, 92, 47, 44, 46, 98], 22: [97, 74, 82, 28], 23: [8, 6, 71, 47], 24: [], 25: [], 26: [30], 27: [], 28: [66, 39, 23, 12, 82, 36], 29: [81, 63, 6, 70, 71], 30: [35, 6, 19, 22], 31: [98, 32], 32: [95, 0, 73, 97, 76, 94, 65], 33: [], 34: [16, 24], 35: [22], 36: [37, 20], 37: [84, 95], 38: [66, 76, 79, 97, 27, 78], 39: [19], 40: [], 41: [94], 42: [54, 91, 5, 31, 57], 43: [64, 45], 44: [], 45: [83, 3, 27], 46: [30, 59, 47, 95], 47: [82], 48: [], 49: [40, 88, 32], 50: [21, 1, 90], 51: [9, 7, 83], 52: [81, 86, 25, 38, 30, 74], 53: [49, 28, 16, 83, 81, 23, 45], 54: [38, 80, 61, 3, 56], 55: [88, 69, 91, 57, 66, 87], 56: [85, 51, 50, 29, 0, 90], 57: [54, 33, 79], 58: [82, 96], 59: [79, 61, 74, 85, 98], 60: [33, 80, 3, 39], 61: [19, 34], 62: [57, 12], 63: [53, 64, 71, 8], 64: [19, 59, 31, 7, 35], 65: [86, 96, 59, 69, 66, 36], 66: [91, 27, 95, 58, 42], 67: [47, 92, 73, 43], 68: [40], 69: [46, 24, 23, 1, 51, 79, 63], 70: [32, 67, 6], 71: [69, 73, 42, 52], 72: [84, 21, 68, 81, 82, 0, 51], 73: [], 74: [48, 26, 83, 70], 75: [], 76: [53, 83, 59, 97, 73, 31, 71], 77: [26], 78: [38, 93, 73, 63], 79: [8], 80: [13, 90], 81: [12, 85, 87, 7, 65], 82: [31, 29, 13, 30, 50], 83: [65, 92, 89, 76, 71, 43, 87], 84: [], 85: [16, 54], 86: [68, 9, 11, 14, 12, 71], 87: [66, 22, 65, 15, 89], 88: [50, 27, 29, 52, 26, 88, 54], 89: [94, 92], 90: [19, 52], 91: [54, 64, 66, 67, 29], 92: [47, 92, 71, 36, 72, 42, 35], 93: [73, 74, 81, 83], 94: [85, 51], 95: [58, 24, 59, 78, 76], 96: [84, 79, 96, 89, 54, 16], 97: [72, 44], 98: [10, 29, 34, 26, 8, 3, 86], 99: [54, 60]}
